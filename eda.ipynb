# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import os
import glob
import numpy as np
import seaborn as sns

# %%
# Load images
image_dir1 = Image.open("data/LibVision-2/train/images/ibmpki8n9vf61_jpg.rf.c6557618c7cd5ddccd17bfcc8d5fa1ac.jpg")
image_dir2 = Image.open("data/Open-Shelves-9/train/images/IMG_2124-Large_jpeg.rf.ab2d08935c922ec4ae5dd6c117838065.jpg")

# Display images 
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(image_dir1)
axes[0].axis('off')
axes[0].set_title('LibVision-2 Sample')

axes[1].imshow(image_dir2)
axes[1].axis('off')
axes[1].set_title('Open-Shelves Sample')

plt.tight_layout()
plt.show()

# %%
# Get all images
libvision_images = glob.glob("data/LibVision-2/train/images/*.jpg")
open_shelves_images = glob.glob("data/Open-Shelves-9/train/images/*.jpg")

# Basic counts
print(f"LibVision-2 images: {len(libvision_images)}")
print(f"Open-Shelves images: {len(open_shelves_images)}") # includes augmented images
# Out:
# LibVision-2 images: 769
# Open-Shelves images: 446
